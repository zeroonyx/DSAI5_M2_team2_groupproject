# %% [markdown]
# # dbt setup

# %%
# !dbt init olist_fulfillment_analysis
# Out:
# 15:19:31  Running with dbt=1.10.9
# 15:19:31
# Your new dbt project "olist_fulfillment_analysis" was created!
#
# For more information on how to configure the profiles.yml file,
# please consult the dbt documentation here:
#
#   https://docs.getdbt.com/docs/configure-your-profile
#
# One more thing:
#
# Need help? Don't hesitate to reach out to us via GitHub issues or on Slack:
#
#   https://community.getdbt.com/
#
# Happy modeling!
#
# 15:19:31  Setting up your profile.
# Which database would you like to use?
# [1] bigquery
#
# (Don't see the one you want? https://docs.getdbt.com/docs/available-adapters)
#
# Enter a number: ^C

# %%
# %cd olist_fulfillment_analysis

# !dbt debug
# Out:
# /Users/ethan/Codes/dsai/DSAI5_M2_team2_groupproject/olist_fulfillment_analysis
# 15:24:54  Running with dbt=1.10.9
# 15:24:54  dbt version: 1.10.9
# 15:24:54  python version: 3.11.14
# 15:24:54  python path: /Users/ethan/miniconda3/envs/elt/bin/python
# 15:24:54  os info: macOS-26.2-arm64-arm-64bit
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780154694.654896 17977661 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_dropped' registered more than once. Ignoring later registration.
# E0000 00:00:1780154694.654915 17977661 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_rejected' registered more than once. Ignoring later registration.
# E0000 00:00:1780154694.654917 17977661 instrument.cc:563] Metric with name 'grpc.resource_quota.connections_dropped' registered more than once. Ignoring later registration.
# ...

# %%
# !dbt snapshot   # only if you created snapshots
# !dbt run
# !dbt test
# Out:
# 17:16:38  Running with dbt=1.10.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780161398.453325 18077476 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_dropped' registered more than once. Ignoring later registration.
# E0000 00:00:1780161398.453396 18077476 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_rejected' registered more than once. Ignoring later registration.
# E0000 00:00:1780161398.453399 18077476 instrument.cc:563] Metric with name 'grpc.resource_quota.connections_dropped' registered more than once. Ignoring later registration.
# E0000 00:00:1780161398.453402 18077476 instrument.cc:563] Metric with name 'grpc.resource_quota.instantaneous_memory_pressure' registered more than once. Ignoring later registration.
# ...
